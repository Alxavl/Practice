# %% [markdown]
# <a href="https://colab.research.google.com/github/Alxavl/Practice/blob/main/notebooks/Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install libraries
# !pip install ts-rnn sktime
# Out:
# Collecting ts-rnn
#   Downloading ts_rnn-0.2.12-py3-none-any.whl.metadata (6.5 kB)
# Collecting sktime
#   Downloading sktime-0.34.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from ts-rnn) (2.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from ts-rnn) (1.26.4)
# Requirement already satisfied: tqdm>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from ts-rnn) (4.66.6)
# Requirement already satisfied: tensorflow>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from ts-rnn) (2.17.0)
# Requirement already satisfied: matplotlib>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ts-rnn) (3.8.0)
# Collecting keras-tuner>=1.0.4 (from ts-rnn)
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: joblib<1.5,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sktime) (24.1)
# Collecting scikit-base<0.12.0,>=0.6.1 (from sktime)
#   Downloading scikit_base-0.11.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: scikit-learn<1.6.0,>=0.24 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.13.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner>=1.0.4->ts-rnn) (3.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner>=1.0.4->ts-rnn) (2.32.3)
# Collecting kt-legacy (from keras-tuner>=1.0.4->ts-rnn)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->ts-rnn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->ts-rnn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->ts-rnn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->ts-rnn) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->ts-rnn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->ts-rnn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->ts-rnn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->ts-rnn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->ts-rnn) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.6.0,>=0.24->sktime) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.1.0->ts-rnn) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1.0->ts-rnn) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner>=1.0.4->ts-rnn) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner>=1.0.4->ts-rnn) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner>=1.0.4->ts-rnn) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.0.4->ts-rnn) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.0.4->ts-rnn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.0.4->ts-rnn) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.0.4->ts-rnn) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.1.0->ts-rnn) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.1.0->ts-rnn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.1.0->ts-rnn) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow>=2.1.0->ts-rnn) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner>=1.0.4->ts-rnn) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner>=1.0.4->ts-rnn) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner>=1.0.4->ts-rnn) (0.1.2)
# Downloading ts_rnn-0.2.12-py3-none-any.whl (13 kB)
# Downloading sktime-0.34.0-py3-none-any.whl (36.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 28.5 MB/s eta 0:00:00
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 7.6 MB/s eta 0:00:00
# Downloading scikit_base-0.11.0-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 7.6 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, scikit-base, sktime, keras-tuner, ts-rnn
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5 scikit-base-0.11.0 sktime-0.34.0 ts-rnn-0.2.12

# %%
#################################           Load libs                      #############################################
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sktime.transformations.series.detrend import Deseasonalizer
# %matplotlib inline

from ts_rnn.model import TS_RNN
from keras_tuner import HyperParameters
from ts_rnn.utils import metrics_eval, train_test_pred_plot

# %% [markdown]
# ## Univariate prediction

# %%
TEST_LEN = 55

# Import targets
data_url = "https://raw.githubusercontent.com/Alxavl/Practice/refs/heads/main/series_g.csv"
target = pd.read_csv(data_url, sep=";").series_g
target_train, target_test = train_test_split(target, test_size=TEST_LEN, shuffle=False)

# %%
# Deseason target
deseason_transformer = Deseasonalizer(sp=6, model='additive')
target_train_deseas = deseason_transformer.fit_transform(target_train)
target_test_deseas = deseason_transformer.transform(target_test)

# Scale target
target_scaler = MinMaxScaler(feature_range=(0, 1))
target_train_std = pd.Series(target_scaler.fit_transform(target_train_deseas.values.reshape(-1, 1)).flatten(), index=target_train.index, name=target.name)
target_test_std = pd.Series(target_scaler.transform(target_test_deseas.values.reshape(-1, 1)).flatten(), index=target_test.index, name=target.name)

# %%
# Create folder for reports
if "reports" not in os.listdir('..'):
    os.makedirs("../reports")
new_folder_num = str(len(os.listdir('../reports')) + 1)
new_folder = os.path.join("../reports", new_folder_num)
os.mkdir(new_folder)
print(f"Save experimnet in {new_folder}")

hp = HyperParameters()
rnn_arch = {"layers": [
                        ["LSTM", {"units": hp.Int(name='units',
                                                 min_value=32,
                                                 max_value=128,
                                                 step=32,
                                                 default=64
                                                ),
                                  "return_sequences": False,
                                  "kernel_initializer": "glorot_uniform",
                                  "activation": hp.Choice(name='LSTM_1_activation',
                                                          values=['relu', 'tanh', 'sigmoid', "linear"],
                                                          default='relu'),
                                  }],
                        ["Dropout", {"rate": hp.Float(name='dropout',
                                                      min_value=0.0,
                                                      max_value=0.5,
                                                      default=0.2,
                                                      step=0.05)
                                     }],
                        ["Dense", {"activation": "linear"}]
                    ]}

model = TS_RNN(rnn_arch=rnn_arch,
               n_lags=52,
               horizon=TEST_LEN,
               tuner_hp=hp,
               tuner="BayesianOptimization", #"RandomSearch", "BayesianOptimization", "Hyperband"
               strategy="MiMo", #"Direct", "Recursive", "MiMo", "DirRec", "DirMo"
               max_trials=3,
               save_dir=new_folder,
               loss="mae",
               optimizer="adam"
               )
# Out:
# Save experimnet in ../reports/4
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.fit(target_train=target_train_std,
          target_val=target_test_std,
          epochs=265,
          batch_size=12,
          verbose=1)

model.summary()
# Out:
# Trial 3 Complete [00h 02m 25s]
# val_loss: 0.08270183950662613
#
# Best val_loss So Far: 0.08270183950662613
# Total elapsed time: 00h 07m 16s
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 12 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# INFO:ts_rnn_logger:[Training] Training ended
# INFO:ts_rnn_logger:[Timing] fit takes: 437.27 sec
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 55)                  │           3,575 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,471 (79.96 KB)
#  Trainable params: 20,471 (79.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
predicted_std = model.predict(target=target_train_std[-model.n_lags:], prediction_len=TEST_LEN)

# inverse transform
predicted_rnn = target_scaler.inverse_transform(predicted_std.reshape(-1, 1)).flatten()
predicted_rnn = pd.Series(predicted_rnn,index=target_test.index)
predicted_rnn = deseason_transformer.inverse_transform(predicted_rnn)

metrics_eval(target_test[:len(predicted_rnn)], predicted_rnn, print_result=True, save_dir=new_folder)
predicted = {"RNN": {"predictions": predicted_rnn}}

train_test_pred_plot(train=target_train, test=target_test, predicted=predicted,
                     save_dir=new_folder, show=True);
# Out:
# INFO:ts_rnn_logger:[Prediction] Start predict by MiMo strategy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# INFO:ts_rnn_logger:[Prediction] End predict by MiMo strategy
# INFO:ts_rnn_logger:[Timing] predict takes: 0.42 sec
# Mean Absolute Error: 11.072
# Mean Squared Error: 405.984
# Symmetric Mean absolute percentage error: 23.262
# Root Mean Squared Error: 20.149
# Mean absolute percentage error: 87.034

# %% [markdown]
# ## Mulrivariate prediction (Target + Factors)

# %%
# Import targets
data_url = "https://raw.githubusercontent.com/LevPerla/Time_Series_Prediction_RNN/master/data/series_g.csv"
target = pd.read_csv(data_url, sep=";").series_g

# Generate factors
f1 = np.arange(1, len(target) + 1).reshape(-1, 1)
f2 = (np.arange(1, len(target) + 1) ** 2).reshape(-1, 1)
factors = pd.DataFrame(np.hstack((f1, f2)))

factors_train, factors_test, target_train, target_test = train_test_split(factors,
                                                                          target,
                                                                          test_size=TEST_LEN,
                                                                          random_state=42,
                                                                          shuffle=False)

# %%
# Deseason target
deseason_transformer = Deseasonalizer(sp=12, model='multiplicative')
target_train_deseas = deseason_transformer.fit_transform(target_train)
target_test_deseas = deseason_transformer.transform(target_test)

# Scale target
target_scaler = MinMaxScaler(feature_range=(0, 1))
target_train_std = pd.Series(target_scaler.fit_transform(target_train_deseas.values.reshape(-1, 1)).flatten(), index=target_train.index, name=target.name)
target_test_std = pd.Series(target_scaler.transform(target_test_deseas.values.reshape(-1, 1)).flatten(), index=target_test.index, name=target.name)

#scale factors
factors_scaler = MinMaxScaler(feature_range=(0, 1))
factors_train_std = pd.DataFrame(factors_scaler.fit_transform(factors_train), index=factors_train.index, columns=factors_train.columns)
factors_test_std = pd.DataFrame(factors_scaler.transform(factors_test), index=factors_test.index, columns=factors_test.columns)

# %%
model = TS_RNN(rnn_arch=rnn_arch,
               n_lags=12,
               horizon=TEST_LEN,
               tuner_hp=hp,
               tuner="BayesianOptimization", #"RandomSearch", "BayesianOptimization", "Hyperband"
               strategy="MiMo", #"Direct", "Recursive", "MiMo", "DirRec", "DirMo"
               max_trials=3,
               save_dir=new_folder,
               loss="mae",
               optimizer="adam",
               n_features=factors_train_std.shape[1]  # also you need to define this if use factors
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Create folder for reports
if "reports" not in os.listdir('..'):
    os.makedirs("../reports")
new_folder_num = str(len(os.listdir('../reports')) + 1)
new_folder = os.path.join("../reports", new_folder_num)
os.mkdir(new_folder)
print(f"Save experimnet in {new_folder}")

model.fit(factors_train=factors_train_std,  # also you need to define this if use factors
          target_train=target_train_std,
          factors_val=factors_test_std,
          target_val=target_test_std,
          epochs=30,
          batch_size=12,
          verbose=1)

model.summary()
# Out:
# Trial 3 Complete [00h 00m 08s]
# val_loss: 0.04339151456952095
#
# Best val_loss So Far: 0.04108482971787453
# Total elapsed time: 00h 00m 23s
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 12 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# INFO:ts_rnn_logger:[Training] Training ended
# INFO:ts_rnn_logger:[Timing] fit takes: 23.49 sec
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          17,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 12)                  │             780 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,188 (71.05 KB)
#  Trainable params: 18,188 (71.05 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
predicted_std = model.predict(
    factors=factors_train_std[-model.n_lags:],  # also you need to define this if use factors
    target=target_train_std[-model.n_lags:],
    prediction_len=TEST_LEN
)

# inverse transform
predicted_rnn = target_scaler.inverse_transform(predicted_std.reshape(-1, 1)).flatten()
predicted_rnn = pd.Series(predicted_rnn,index=target_test.index)
predicted_rnn = deseason_transformer.inverse_transform(predicted_rnn)

metrics_eval(target_test[:len(predicted_rnn)], predicted_rnn, print_result=True, save_dir=new_folder)
train_test_pred_plot(train=target_train, test=target_test, predicted=predicted_rnn, save_dir=new_folder);
# Out:
# INFO:ts_rnn_logger:[Prediction] Start predict by MiMo strategy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# INFO:ts_rnn_logger:[Prediction] End predict by MiMo strategy
# INFO:ts_rnn_logger:[Timing] predict takes: 0.22 sec
# Mean Absolute Error: 13.62
# Mean Squared Error: 378.38
# Symmetric Mean absolute percentage error: 2.893
# Root Mean Squared Error: 19.452
# Mean absolute percentage error: 2.948
